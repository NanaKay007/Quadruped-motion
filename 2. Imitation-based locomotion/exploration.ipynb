# %%
import genesis as gs
gs.init(backend=gs.metal)
# Out:
# [Genesis] [17:24:07] [INFO] ╭───────────────────────────────────────────────╮
# [Genesis] [17:24:07] [INFO] │┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈ Genesis ┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈┉┈│
# [Genesis] [17:24:07] [INFO] ╰───────────────────────────────────────────────╯
# [Genesis] [17:24:07] [INFO] Running on [Apple M4] with backend gs.metal. Device memory: 16.00 GB.
# [Genesis] [17:24:07] [INFO] 🚀 Genesis initialized. 🔖 version: 0.4.1, 🎨 theme: dark, 🌱 seed: None, 🐛 debug: False, 📏 precision: 32, 🔥 performance: False, 💬 verbose: INFO
